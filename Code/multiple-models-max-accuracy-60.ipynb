# %% [markdown]
# **# Using Decision Trees**

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Load the data
train_data = pd.read_csv('/kaggle/input/customer/Train.csv')
test_data = pd.read_csv('/kaggle/input/customer/Test.csv')

# Separate target variable from features in training data
X_train_full = train_data.drop(['ID', 'Segmentation'], axis=1)
y_train_full = train_data['Segmentation']

# Separate ID column from test features
test_ids = test_data['ID']
X_test = test_data.drop('ID', axis=1)

# Handle missing values
X_train_full.fillna(method='ffill', inplace=True)
X_test.fillna(method='ffill', inplace=True)

# Encode categorical variables
cat_cols = ['Gender', 'Ever_Married', 'Graduated', 'Profession', 'Spending_Score', 'Var_1']
for col in cat_cols:
    le = LabelEncoder()
    X_train_full[col] = le.fit_transform(X_train_full[col])
    X_test[col] = le.transform(X_test[col])

# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train_full, y_train_full, test_size=0.2, random_state=42)

# Initialize the Decision Tree Classifier
clf = DecisionTreeClassifier(random_state=42)

# Fit the model on training data
clf.fit(X_train, y_train)

# Predict on validation set
y_pred_val = clf.predict(X_val)

# Calculate accuracy on validation set
val_accuracy = accuracy_score(y_val, y_pred_val)
print(f"Validation Accuracy: {val_accuracy}")

# Predict segments for test data
test_predictions = clf.predict(X_test)

# Create a DataFrame to store the predictions along with 'ID'
submission_df = pd.DataFrame({'ID': test_ids, 'Segmentation': test_predictions})

# Save the predictions to a CSV file
submission_df.to_csv('predicted_segments.csv', index=False)
# Out:
# Validation Accuracy: 0.4281288723667906

# %% [markdown]
# **Random Forest**

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Load the data
train_data = pd.read_csv('/kaggle/input/customer/Train.csv')
test_data = pd.read_csv('/kaggle/input/customer/Test.csv')

# Separate target variable from features in training data
X_train_full = train_data.drop(['ID', 'Segmentation'], axis=1)
y_train_full = train_data['Segmentation']

# Separate ID column from test features
test_ids = test_data['ID']
X_test = test_data.drop('ID', axis=1)

# Handle missing values
X_train_full.fillna(method='ffill', inplace=True)
X_test.fillna(method='ffill', inplace=True)

# Encode categorical variables
cat_cols = ['Gender', 'Ever_Married', 'Graduated', 'Profession', 'Spending_Score', 'Var_1']
for col in cat_cols:
    le = LabelEncoder()
    X_train_full[col] = le.fit_transform(X_train_full[col])
    X_test[col] = le.transform(X_test[col])

# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train_full, y_train_full, test_size=0.2, random_state=42)

# Initialize the Random Forest Classifier
clf = RandomForestClassifier(n_estimators=100, random_state=42)

# Fit the model on training data
clf.fit(X_train, y_train)

# Predict on validation set
y_pred_val = clf.predict(X_val)

# Calculate accuracy on validation set
val_accuracy = accuracy_score(y_val, y_pred_val)
print(f"Validation Accuracy with Random Forest Classifier: {val_accuracy}")

# Predict segments for test data
test_predictions = clf.predict(X_test)

# Create a DataFrame to store the predictions along with 'ID'
submission_df = pd.DataFrame({'ID': test_ids, 'Segmentation': test_predictions})

# Save the predictions to a CSV file
submission_df.to_csv('predicted_segments.csv', index=False)
# Out:
# Validation Accuracy with Random Forest Classifier: 0.48451053283767037

# %% [markdown]
# **GridSearchCV**

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Load the data
train_data = pd.read_csv('/kaggle/input/customer/Train.csv')
test_data = pd.read_csv('/kaggle/input/customer/Test.csv')

# Separate target variable from features in training data
X_train_full = train_data.drop(['ID', 'Segmentation'], axis=1)
y_train_full = train_data['Segmentation']

# Separate ID column from test features
test_ids = test_data['ID']
X_test = test_data.drop('ID', axis=1)

# Handle missing values
X_train_full.fillna(method='ffill', inplace=True)
X_test.fillna(method='ffill', inplace=True)

# Encode categorical variables
cat_cols = ['Gender', 'Ever_Married', 'Graduated', 'Profession', 'Spending_Score', 'Var_1']
for col in cat_cols:
    le = LabelEncoder()
    X_train_full[col] = le.fit_transform(X_train_full[col])
    X_test[col] = le.transform(X_test[col])

# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train_full, y_train_full, test_size=0.2, random_state=42)

# Define the parameter grid
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20],
    # Add more parameters to tune
}

# Initialize the Random Forest Classifier
clf = RandomForestClassifier(random_state=42)

# Initialize GridSearchCV
grid_search = GridSearchCV(clf, param_grid, cv=5, scoring='accuracy')

# Fit the grid search to the data
grid_search.fit(X_train, y_train)

# Get the best parameters and the best estimator
best_params = grid_search.best_params_
best_estimator = grid_search.best_estimator_

# Use the best estimator for prediction and evaluation
y_pred_val = best_estimator.predict(X_val)
val_accuracy = accuracy_score(y_val, y_pred_val)
print(f"Improved Validation Accuracy: {val_accuracy} with parameters: {best_params}")

# Predict segments for test data
test_predictions = best_estimator.predict(X_test)

# Create a DataFrame to store the predictions along with 'ID'
submission_df = pd.DataFrame({'ID': test_ids, 'Segmentation': test_predictions})

# Save the predictions to a CSV file
submission_df.to_csv('predicted_segments.csv', index=False)
# Out:
# Improved Validation Accuracy: 0.5179677819083024 with parameters: {'max_depth': 10, 'n_estimators': 300}

# %%
# !pip install optuna
# Out:
# Requirement already satisfied: optuna in /opt/conda/lib/python3.10/site-packages (3.4.0)
# Requirement already satisfied: alembic>=1.5.0 in /opt/conda/lib/python3.10/site-packages (from optuna) (1.12.1)
# Requirement already satisfied: colorlog in /opt/conda/lib/python3.10/site-packages (from optuna) (6.7.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from optuna) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from optuna) (21.3)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from optuna) (2.0.20)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from optuna) (4.66.1)
# Requirement already satisfied: PyYAML in /opt/conda/lib/python3.10/site-packages (from optuna) (6.0.1)
# Requirement already satisfied: Mako in /opt/conda/lib/python3.10/site-packages (from alembic>=1.5.0->optuna) (1.3.0)
# Requirement already satisfied: typing-extensions>=4 in /opt/conda/lib/python3.10/site-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->optuna) (3.0.9)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.10/site-packages (from sqlalchemy>=1.3.0->optuna) (2.0.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /opt/conda/lib/python3.10/site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import optuna

# Load the data
train_data = pd.read_csv('/kaggle/input/customer/Train.csv')
test_data = pd.read_csv('/kaggle/input/customer/Test.csv')

# Separate target variable from features in training data
X_train_full = train_data.drop(['ID', 'Segmentation'], axis=1)
y_train_full = train_data['Segmentation']

# Separate ID column from test features
test_ids = test_data['ID']
X_test = test_data.drop('ID', axis=1)

# Handle missing values
X_train_full.fillna(method='ffill', inplace=True)
X_test.fillna(method='ffill', inplace=True)

# Encode categorical variables
cat_cols = ['Gender', 'Ever_Married', 'Graduated', 'Profession', 'Spending_Score', 'Var_1']
for col in cat_cols:
    le = LabelEncoder()
    X_train_full[col] = le.fit_transform(X_train_full[col])
    X_test[col] = le.transform(X_test[col])

# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train_full, y_train_full, test_size=0.2, random_state=42)

# Define the objective function for optimization
def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 500),
        'max_depth': trial.suggest_int('max_depth', 3, 20),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 20),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 10),
        'max_features': trial.suggest_categorical('max_features', ['auto', 'sqrt', 'log2']),
        # Add more parameters to tune
    }
    
    clf = RandomForestClassifier(**params)
    clf.fit(X_train, y_train)
    
    y_pred = clf.predict(X_val)
    return 1.0 - accuracy_score(y_val, y_pred)

# Perform Bayesian optimization with Optuna
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=100)

# Get the best parameters
best_params = study.best_params
print(f"Best Parameters: {best_params}")

# Use the best parameters for training the final model
best_clf = RandomForestClassifier(**best_params)
best_clf.fit(X_train_full, y_train_full)

# Predict segments for test data using the best model
test_predictions = best_clf.predict(X_test)

# Create a DataFrame to store the predictions along with 'ID'
submission_df = pd.DataFrame({'ID': test_ids, 'Segmentation': test_predictions})

# Save the predictions to a CSV file
submission_df.to_csv('predicted_segments.csv', index=False)
# Out:
# [I 2023-11-24 17:09:15,606] A new study created in memory with name: no-name-ea7578a0-a800-4676-8474-bb87dca97e78
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [I 2023-11-24 17:09:16,596] Trial 0 finished with value: 0.4851301115241635 and parameters: {'n_estimators': 207, 'max_depth': 4, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': 'auto'}. Best is trial 0 with value: 0.4851301115241635.
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [I 2023-11-24 17:09:18,563] Trial 1 finished with value: 0.4826517967781908 and parameters: {'n_estimators': 362, 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'auto'}. Best is trial 1 with value: 0.4826517967781908.
# [I 2023-11-24 17:09:20,589] Trial 2 finished with value: 0.48822800495662955 and parameters: {'n_estimators': 254, 'max_depth': 20, 'min_samples_split': 11, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.4826517967781908.
# [I 2023-11-24 17:09:22,390] Trial 3 finished with value: 0.476456009913259 and parameters: {'n_estimators': 335, 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 9, 'max_features': 'log2'}. Best is trial 3 with value: 0.476456009913259.
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [I 2023-11-24 17:09:23,575] Trial 4 finished with value: 0.46468401486988853 and parameters: {'n_estimators': 182, 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 9, 'max_features': 'auto'}. Best is trial 4 with value: 0.46468401486988853.
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [I 2023-11-24 17:09:25,232] Trial 5 finished with value: 0.47273853779429986 and parameters: {'n_estimators': 286, 'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 8, 'max_features': 'auto'}. Best is trial 4 with value: 0.46468401486988853.
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [I 2023-11-24 17:09
 'max_depth': 14, 'min_samples_split': 5, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 4 with value: 0.46468401486988853.
# [I 2023-11-24 17:11:21,224] Trial 60 finished with value: 0.4783147459727385 and parameters: {'n_estimators': 196, 'max_depth': 15, 'min_samples_split': 5, 'min_samples_leaf': 9, 'max_features': 'log2'}. Best is trial 4 with value: 0.46468401486988853.
# [I 2023-11-24 17:11:22,419] Trial 61 finished with value: 0.47149938042131345 and parameters: {'n_estimators': 171, 'max_depth': 14, 'min_samples_split': 3, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 4 with value: 0.46468401486988853.
# [I 2023-11-24 17:11:23,930] Trial 62 finished with value: 0.46964064436183395 and parameters: {'n_estimators': 219, 'max_depth': 13, 'min_samples_split': 4, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 4 with value: 0.46468401486988853.
# [I 2023-11-24 17:11:25,746] Trial 63 finished with value: 0.4820322180916976 and parameters: {'n_estimators': 242, 'max_depth': 11, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 4 with value: 0.46468401486988853.
# [I 2023-11-24 17:11:27,905] Trial 64 finished with value: 0.47149938042131345 and parameters: {'n_estimators': 313, 'max_depth': 19, 'min_samples_split': 2, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 4 with value: 0.46468401486988853.
# [I 2023-11-24 17:11:28,923] Trial 65 finished with value: 0.47087980173482036 and parameters: {'n_estimators': 152, 'max_depth': 9, 'min_samples_split': 20, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 4 with value: 0.46468401486988853.
# [I 2023-11-24 17:11:30,305] Trial 66 finished with value: 0.476456009913259 and parameters: {'n_estimators': 187, 'max_depth': 12, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': 'sqrt'}. Best is trial 4 with value: 0.46468401486988853.
# [I 2023-11-24 17:11:31,147] Trial 67 finished with value: 0.47149938042131345 and parameters: {'n_estimators': 134, 'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 10, 'max_features': 'sqrt'}. Best is trial 4 with value: 0.46468401486988853.
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [I 2023-11-24 17:11:33,832] Trial 68 finished with value: 0.46716232961586124 and parameters: {'n_estimators': 390, 'max_depth': 16, 'min_samples_split': 8, 'min_samples_leaf': 9, 'max_features': 'auto'}. Best is trial 4 with value: 0.46468401486988853.
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [I 2023-11-24 17:11:36,472] Trial 69 finished with value: 0.4745972738537795 and parameters: {'n_estimators': 379, 'max_depth': 17, 'min_samples_split': 9, 'min_samples_leaf': 8, 'max_features': 'auto'}. Best is trial 4 with value: 0.46468401486988853.
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [I 2023-11-24 17:11:38,019] Trial 70 finished with value: 0.4745972738537795 and parameters: {'n_estimators': 212, 'max_depth': 16, 'min_samples_split': 7, 'min_samples_leaf': 7, 'max_features': 'auto'}. Best is trial 4 with value: 0.46468401486988853.
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [I 2023-11-24 17:11:40,720] Trial 71 finished with value: 0.47149938042131345 and parameters: {'n_estimators': 394, 'max_depth': 15, 'min_samples_split': 11, 'min_samples_leaf': 9, 'max_features': 'auto'}. Best is trial 4 with value: 0.46468401486988853.
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [I 2023-11-24 17:11:43,485] Trial 72 finished with value: 0.47087980173482036 and parameters: {'n_estimators': 393, 'max_depth': 16, 'min_samples_split': 8, 'min_samples_leaf': 9, 'max_features': 'auto'}. Best is trial 4 with value: 0.46468401486988853.
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [I 2023-11-24 17:11:46,526] Trial 73 finished with value: 0.46840148698884754 and parameters: {'n_estimators': 473, 'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 9, 'max_features': 'auto'}. Best is trial 4 with value: 0.46468401486988853.
# [I 2023-11-24 17:11:49,445] Trial 74 finished with value: 0.47335811648079307 and parameters: {'n_estimators': 440, 'max_depth': 17, 'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': 'sqrt'}. Best is trial 4 with value: 0.46468401486988853.
# [I 2023-11-24 17:11:52,006] Trial 75 finished with value: 0.4628252788104089 and parameters: {'n_estimators': 412, 'max_depth': 8, 'min_samples_split': 18, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 75 with value: 0.4628252788104089.
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [I 2023-11-24 17:11:54,304] Trial 76 finished with value: 0.47149938042131345 and parameters: {'n_estimators': 371, 'max_depth': 8, 'min_samples_split': 18, 'min_samples_leaf': 8, 'max_features': 'auto'}. Best is trial 75 with value: 0.4628252788104089.
# [I 2023-11-24 17:11:55,138] Trial 77 finished with value: 0.47273853779429986 and parameters: {'n_estimators': 116, 'max_depth': 18, 'min_samples_split': 10, 'min_samples_leaf': 9, 'max_features': 'log2'}. Best is trial 75 with value: 0.4628252788104089.
# [I 2023-11-24 17:11:57,347] Trial 78 finished with value: 0.46654275092936803 and parameters: {'n_estimators': 359, 'max_depth': 8, 'min_samples_split': 13, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 75 with value: 0.4628252788104089.
# [I 2023-11-24 17:11:59,312] Trial 79 finished with value: 0.47521685254027257 and parameters: {'n_estimators': 360, 'max_depth': 6, 'min_samples_split': 13, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 75 with value: 0.4628252788104089.
# [I 2023-11-24 17:12:01,749] Trial 80 finished with value: 0.47521685254027257 and parameters: {'n_estimators': 417, 'max_depth': 7, 'min_samples_split': 15, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 75 with value: 0.4628252788104089.
# [I 2023-11-24 17:12:03,897] Trial 81 finished with value: 0.47026022304832715 and parameters: {'n_estimators': 347, 'max_depth': 8, 'min_samples_split': 14, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 75 with value: 0.4628252788104089.
# [I 2023-11-24 17:12:06,512] Trial 82 finished with value: 0.46716232961586124 and parameters: {'n_estimators': 406, 'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 75 with value: 0.4628252788104089.
# [I 2023-11-24 17:12:08,671] Trial 83 finished with value: 0.4640644361833953 and parameters: {'n_estimators': 332, 'max_depth': 9, 'min_samples_split': 11, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 75 with value: 0.4628252788104089.
# [I 2023-11-24 17:12:10,833] Trial 84 finished with value: 0.46716232961586124 and parameters: {'n_estimators': 331, 'max_depth': 9, 'min_samples_split': 11, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 75 with value: 0.4628252788104089.
# [I 2023-11-24 17:12:13,053] Trial 85 finished with value: 0.46716232961586124 and parameters: {'n_estimators': 340, 'max_depth': 9, 'min_samples_split': 12, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 75 with value: 0.4628252788104089.
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [I 2023-11-24 17:12:15,299] Trial 86 finished with value: 0.47026022304832715 and parameters: {'n_estimators': 328, 'max_depth': 10, 'min_samples_split': 11, 'min_samples_leaf': 6, 'max_features': 'auto'}. Best is trial 75 with value: 0.4628252788104089.
# [I 2023-11-24 17:12:17,719] Trial 87 finished with value: 0.47026022304832715 and parameters: {'n_estimators': 365, 'max_depth': 10, 'min_samples_split': 11, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 75 with value: 0.4628252788104089.
# [I 2023-11-24 17:12:19,878] Trial 88 finished with value: 0.4758364312267658 and parameters: {'n_estimators': 316, 'max_depth': 11, 'min_samples_split': 10, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 75 with value: 0.4628252788104089.
# [I 2023-11-24 17:12:22,523] Trial 89 finished with value: 0.4628252788104089 and parameters: {'n_estimators': 405, 'max_depth': 9, 'min_samples_split': 13, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 75 with value: 0.4628252788104089.
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [I 2023-11-24 17:12:24,307] Trial 90 finished with value: 0.49504337050805447 and parameters: {'n_estimators': 402, 'max_depth': 3, 'min_samples_split': 13, 'min_samples_leaf': 7, 'max_features': 'auto'}. Best is trial 75 with value: 0.4628252788104089.
# [I 2023-11-24 17:12:26,758] Trial 91 finished with value: 0.47087980173482036 and parameters: {'n_estimators': 382, 'max_depth': 9, 'min_samples_split': 12, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 75 with value: 0.4628252788104089.
# [I 2023-11-24 17:12:29,307] Trial 92 finished with value: 0.47087980173482036 and parameters: {'n_estimators': 418, 'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 75 with value: 0.4628252788104089.
# [I 2023-11-24 17:12:31,451] Trial 93 finished with value: 0.46778190830235444 and parameters: {'n_estimators': 330, 'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 75 with value: 0.4628252788104089.
# [I 2023-11-24 17:12:33,511] Trial 94 finished with value: 0.4739776951672863 and parameters: {'n_estimators': 351, 'max_depth': 7, 'min_samples_split': 13, 'min_samples_leaf': 6, 'max_features': 'sqrt'}. Best is trial 75 with value: 0.4628252788104089.
# [I 2023-11-24 17:12:35,557] Trial 95 finished with value: 0.47273853779429986 and parameters: {'n_estimators': 305, 'max_depth': 10, 'min_samples_split': 15, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 75 with value: 0.4628252788104089.
# [I 2023-11-24 17:12:37,936] Trial 96 finished with value: 0.46964064436183395 and parameters: {'n_estimators': 360, 'max_depth': 10, 'min_samples_split': 14, 'min_samples_leaf': 9, 'max_features': 'log2'}. Best is trial 75 with value: 0.4628252788104089.
# [I 2023-11-24 17:12:40,308] Trial 97 finished with value: 0.47087980173482036 and parameters: {'n_estimators': 386, 'max_depth': 8, 'min_samples_split': 8, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 75 with value: 0.4628252788104089.
# [I 2023-11-24 17:12:43,073] Trial 98 finished with value: 0.47026022304832715 and parameters: {'n_estimators': 405, 'max_depth': 11, 'min_samples_split': 13, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 75 with value: 0.4628252788104089.
# [I 2023-11-24 17:12:45,862] Trial 99 finished with value: 0.46964064436183395 and parameters: {'n_estimators': 425, 'max_depth': 9, 'min_samples_split': 11, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 75 with value: 0.4628252788104089.
# Best Parameters: {'n_estimators': 412, 'max_depth': 8, 'min_samples_split': 18, 'min_samples_leaf': 8, 'max_features': 'sqrt'}

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import optuna

# Load the data
train_data = pd.read_csv('/kaggle/input/customer/Train.csv')
test_data = pd.read_csv('/kaggle/input/customer/Test.csv')

# Separate target variable from features in training data
X_train_full = train_data.drop(['ID', 'Segmentation'], axis=1)
y_train_full = train_data['Segmentation']

# Separate ID column from test features
test_ids = test_data['ID']
X_test = test_data.drop('ID', axis=1)

# Handle missing values
X_train_full.fillna(method='ffill', inplace=True)
X_test.fillna(method='ffill', inplace=True)

# Encode categorical variables
cat_cols = ['Gender', 'Ever_Married', 'Graduated', 'Profession', 'Spending_Score', 'Var_1']
for col in cat_cols:
    le = LabelEncoder()
    X_train_full[col] = le.fit_transform(X_train_full[col])
    X_test[col] = le.transform(X_test[col])

# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train_full, y_train_full, test_size=0.2, random_state=42)

# Define the objective function for optimization
def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 500),
        'max_depth': trial.suggest_int('max_depth', 3, 20),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 20),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 10),
        'max_features': trial.suggest_categorical('max_features', ['auto', 'sqrt', 'log2']),
        # Add more parameters to tune
    }
    
    clf = RandomForestClassifier(**params)
    clf.fit(X_train, y_train)
    
    y_pred = clf.predict(X_val)
    return 1.0 - accuracy_score(y_val, y_pred)

# Perform Bayesian optimization with Optuna
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=100)

# Get the best parameters
best_params = study.best_params
print(f"Best Parameters: {best_params}")

# Use the best parameters for training the final model
best_clf = RandomForestClassifier(**best_params)
best_clf.fit(X_train_full, y_train_full)

# Predict segments for validation data using the best model
val_predictions = best_clf.predict(X_val)

# Calculate validation accuracy
val_accuracy = accuracy_score(y_val, val_predictions)
print(f"Validation Accuracy with Best Parameters: {val_accuracy}")

# Predict segments for test data using the best model
test_predictions = best_clf.predict(X_test)

# Create a DataFrame to store the predictions along with 'ID'
submission_df = pd.DataFrame({'ID': test_ids, 'Segmentation': test_predictions})

# Save the predictions to a CSV file
submission_df.to_csv('predicted_segments.csv', index=False)
# Out:
# [I 2023-11-24 17:12:48,903] A new study created in memory with name: no-name-09d3fa8b-2804-438a-b891-93bd16b07f99
# [I 2023-11-24 17:12:51,640] Trial 0 finished with value: 0.476456009913259 and parameters: {'n_estimators': 471, 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 9, 'max_features': 'log2'}. Best is trial 0 with value: 0.476456009913259.
# [I 2023-11-24 17:12:52,669] Trial 1 finished with value: 0.48760842627013634 and parameters: {'n_estimators': 219, 'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.476456009913259.
# [I 2023-11-24 17:12:53,803] Trial 2 finished with value: 0.49070631970260226 and parameters: {'n_estimators': 266, 'max_depth': 3, 'min_samples_split': 20, 'min_samples_leaf': 5, 'max_features': 'log2'}. Best is trial 0 with value: 0.476456009913259.
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [I 2023-11-24 17:12:54,706] Trial 3 finished with value: 0.4807930607187113 and parameters: {'n_estimators': 115, 'max_depth': 12, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'auto'}. Best is trial 0 with value: 0.476456009913259.
# [I 2023-11-24 17:12:55,467] Trial 4 finished with value: 0.4783147459727385 and parameters: {'n_estimators': 151, 'max_depth': 5, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.476456009913259.
# [I 2023-11-24 17:12:57,303] Trial 5 finished with value: 0.4857496902106567 and parameters: {'n_estimators': 218, 'max_depth': 19, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.476456009913259.
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [I 2023-11-24 17:12:58,112] Trial 6 finished with value: 0.4783147459727385 and parameters: {'n_estimators': 118, 'max_depth': 11, 'min_samples_split': 16, 'min_samples_leaf': 7, 'max_features': 'auto'}. Best is trial 0 with value: 0.476456009913259.
# [I 2023-11-24 17:13:00,747] Trial 7 finished with value: 0.4776951672862454 and parameters: {'n_estimators': 360, 'max_depth': 20, 'min_samples_split': 20, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.476456009913259.
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [I 2023-11-24 17:13:03,305] Trial 8 finished with value: 0.47211895910780666 and parameters: {'n_estimators': 361, 'max_depth': 18, 'min_samples_split': 14, 'min_samples_leaf': 7, 'max_features': 'auto'}. Best is trial 8 with value: 0.47211895910780666.
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [I 2023-11-24 17:13:05,168] Trial 9 finished with value: 0.49008674101610905 and parameters: {'n_estimators': 395, 'max_depth': 4, 'min_samples_split': 8, 'min_samples_leaf': 1, 'max_features': 'auto'}. Best is trial 8 with value: 0.47211895910780666.
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [I 2023-11-24 17:13:08,619] Trial 10 finished with value: 0.47521685254027257 and parameters: {'n_estimators': 476, 'max_depth': 16, 'min_samples_split': 14, 'min_samples_leaf': 5, 'max_features': 'auto'}. Best is trial 8 with value: 0.47211895910780666.
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [I 2023-11-24 17:13:12,119] Trial 11 finished with value: 0.4758364312267658 and parameters: {'n_estimators': 477, 'max_depth': 16, 'min_samples_split': 14, 'min_samples_leaf': 5, 'max_features': 'auto'}. Best is trial 8 with value: 0.47211895910780666.
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [I 2023-11-24 17:13:14,885] Trial 12 finished with value: 0.46964064436183395 and parameters: {'n_estimators': 391, 'max_depth': 16, 'min_samples_split': 14, 'min_samples_leaf': 7, 'max_features': 'auto'}. Best is trial 12 with value: 0.46964064436183395.
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [I 2023-11-24 17:13:17,545] Trial 13 finished with value: 0.47211895910780666 and parameters: {'n_estimators': 367, 'max_depth': 16, 'min_samples_split': 16, 'min_samples_leaf': 7, 'max_features': 'auto'}. Best is trial 12 with value: 0.46964064436183395.
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [I 2023-11-24 17:13:19,772] Trial 14 finished with value: 0.47521685254027257 and parameters: {'n_estimators': 310, 'max_depth': 13, 'min_samples_split': 13, 'min_samples_leaf': 7, 'max_features': 'auto'}. Best is trial 12 with value: 0.46964064436183395.
# /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [I 2023-11-24 17:13:22,665] Trial 15 finished with value: 0.47211895910780666 and parameters: {'n_estimators': 422, 'max_depth': 18, 'min_samples_split': 17, 'min_samples_leaf': 10, 'max_features': 'auto'}. Best is trial 12 with value: 0.46964064436183395.
# [I 2023-11-24 17:13:24,841] Trial 16 finished with value: 0.46964064436183395 and parameters: {'n_estimators': 315, 'max_depth': 14, 'min_samples_split': 11, 'min_samples_leaf': 8, 'max_features': 'log2'}. Best is trial 12 with value: 0.46964064436183395.
# [I 2023-11-24 17:13:26,801] Trial 17 finished with value: 0.46840148698884754 and parameters: {'n_estimators': 303, 'max_depth': 9, 'min_samples_split': 11, 'min_samples_leaf': 8, 'max_features': 'log2'}. Best is trial 17 with value: 0.46840148698884754.
# [I 2023-11-24 17:13:28,568] Trial 18 finished with value: 0.47273853779429986 and parameters: {'n_estimators': 271, 'max_depth': 9, 'min_samples_split': 12, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial